# %% [markdown]
#  # TODO
#  -  Anomaly Detectio
# - error_group повний аналіз
# - card_mask_hash unique cards per user
# - Geographic mismatches (card_country vs reg_country vs payment_country)
# - status fail rate per user
# - card_holder vs email name matching
# - transaction_type distribution per fraud class
# - Amount distribution (log-scale, характерні суми)
# - Time gap: registration → first transaction
# - оформити список користних фіч та їх коіфіціенти
#
# 15.03
# -  Bayesian smoothing для Fraud rate по країнах
# - додати булеві занчення, по тому чи reg_country  == card_country  == payment_country, reg_country == card_country, payment_country == card_country
# - fail_status_coefficient  дає імпакт
# - додати койфіціент по кожній з error_group
# - country_CP_missmatch_coef дає хороший імпакт
# - unique_cards_per_user має великий імпакт до is_fraud
#
#
# **ідеї для feature engineering**
# - розбити пошти на категорії по доменам
# - додати ознаки чи транзакція вночі чи вдень
# - порівнювати card_holder з оригінальним юзер емейлом та з гендером

# %% [markdown]
# # Feature Impact Summary (Updated)
#
# ## Числові фічі (AUC + Point-Biserial)
#
# | # | Feature | AUC | Corr | Сила | Тип | Рішення |
# |---|---------|-----|------|------|-----|---------|
# | 1 | errors_x_cards | **0.8424** | 0.2139 | Відмінна | interaction | ✅ |
# | 2 | holders_x_cards | **0.8284** | 0.1730 | Відмінна | interaction | ✅ |
# | 3 | unique_card_holders | **0.8035** | 0.3249 | Відмінна | diversity | ✅ |
# | 4 | unique_error_types | **0.8025** | 0.2836 | Відмінна | diversity | ✅ |
# | 5 | unique_cards_per_user | **0.7967** | 0.2896 | Відмінна | diversity | ✅ |
# | 6 | tx_count | **0.7292** | 0.1207 | Добра | volume | ✅ |
# | 7 | fail_status_coefficient | **0.7141** | 0.1511 | Добра | error | ✅ |
# | 8 | countries_per_tx | 0.6986 | -0.1366 | Помірна | ratio | ✅ |
# | 9 | min_time_between_tx | 0.6962 | -0.0244 | Помірна | velocity | ✅ |
# | 10 | amount_sum | 0.6956 | 0.1019 | Помірна | amount | ✅ |
# | 11 | unique_card_brands | 0.6745 | 0.2139 | Помірна | diversity | ✅ |
# | 12 | unique_card_types | 0.6687 | 0.2098 | Помірна | diversity | ✅ |
# | 13 | country_CP_mismatch_coef | 0.6633 | 0.1524 | Помірна | geo mismatch | ✅ |
# | 14 | error_antifraud_rate | 0.6596 | 0.2725 | Помірна | error | ✅ |
# | 15 | errors_per_tx | 0.6461 | 0.0496 | Помірна | ratio | ✅ |
# | 16 | country_CReg_mismatch | 0.6434 | 0.1622 | Помірна | geo mismatch | ✅ |
# | 17 | fraud_error_count | 0.6308 | 0.1327 | Помірна | error | ✅ |
# | 18 | holders_per_card | 0.6167 | -0.0049 | Слабка+ | ratio | ✅ |
# | 19 | fraud_error_rate | 0.6163 | 0.0626 | Слабка+ | error | ✅ |
# | 20 | tx_type_card_init_rate | 0.5925 | 0.0612 | Слабка | tx type | ✅ |
# | 21 | error_3ds_error_rate | 0.5798 | 0.0036 | Слабка | error | ✅ |
# | 22 | holders_per_tx | 0.5691 | 0.0109 | Слабка | ratio | ✅ |
# | 23 | amount_range | 0.5637 | 0.0872 | Слабка | amount | ✅ |
# | 24 | error_card_problem_rate | 0.5590 | 0.0610 | Слабка | error | ⚠️ можна спробувати |
# | 25 | amount_std | 0.5557 | 0.0467 | Слабка | amount | ⚠️ можна спробувати |
# | 26 | amount_cv | 0.5545 | 0.0447 | Слабка | amount | ❌ дублює amount_std |
# | 27 | error_do_not_honor_rate | 0.5557 | 0.0001 | Слабка | error | ❌ p=0.95, не значущий |
# | 28 | time_to_first_transaction | 0.5537 | -0.0168 | Слабка | temporal | ⚠️ можна спробувати |
# | 29 | cards_per_tx | 0.5522 | -0.0599 | Слабка | ratio | ❌ дублює countries_per_tx |
# | 30 | error_insuff_funds_rate | 0.5518 | -0.0162 | Слабка | error | ❌ слабкий сигнал |
# | 31 | name_in_email | 0.5499 | -0.0413 | Слабка | identity | ⚠️ можна спробувати |
# | 32 | unique_card_countries | 0.5493 | 0.1266 | Слабка | diversity | ❌ дублює countries_per_tx |
# | 33 | avg_time_between_tx | 0.5491 | -0.0314 | Слабка | velocity | ❌ min_time краще |
# | 34 | tx_type_resign_rate | 0.5422 | 0.0382 | Слабка | tx type | ❌ слабкий сигнал |
# | 35 | std_time_between_tx | 0.5410 | -0.0295 | Слабка | velocity | ❌ min_time краще |
# | 36 | tx_type_card_recurring_rate | 0.5302 | 0.0094 | Шум | tx type | ❌ |
# | 37 | cvv_error_coef | 0.5302 | 0.0007 | Шум | error | ❌ p=0.67 |
# | 38 | amount_max | 0.5296 | 0.0836 | Шум | amount | ❌ |
# | 39 | tx_type_google-pay_rate | 0.5199 | -0.0514 | Шум | tx type | ❌ |
# | 40 | tx_type_apple-pay_rate | 0.5174 | -0.0385 | Шум | tx type | ❌ |
# | 41 | amount_mean | 0.5161 | 0.0428 | Шум | amount | ❌ |
# | 42 | reg_is_night | 0.5018 | -0.0015 | Шум | temporal | ❌ p=0.35 |
# | 43 | reg_hour | 0.5016 | -0.0010 | Шум | temporal | ❌ p=0.54 |
#
# ## Бінарні фічі (Phi Coefficient)
#
# | # | Feature | Phi (φ) | p-value | Сила | Рішення |
# |---|---------|---------|---------|------|---------|
# | 1 | is_cvv_error | 0.0256 | 3.75e-58 | Дуже слабка | ❌ |
#
# ## Категоріальні фічі (Theil's U → is_fraud)
#
# | # | Feature | Theil's U | Сила | Рішення |
# |---|---------|-----------|------|---------|
# | 1 | card_country | 0.0251 | Помірна | ✅ target encode |
# | 2 | payment_country | 0.0241 | Помірна | ❌ дублює card_country |
# | 3 | reg_country | 0.0240 | Помірна | ✅ target encode |
# | 4 | gender | 0.0175 | Слабка | ✅ target encode |
# | 5 | status | 0.0117 | Слабка | ❌ вже є fail_status_coefficient |
# | 6 | traffic_type | 0.0087 | Слабка | ✅ target encode |
# | 7 | card_type | 0.0051 | Дуже слабка | ❌ вже є unique_card_types |
# | 8 | domain | 0.0046 | Дуже слабка | ⚠️ можна спробувати |
# | 9 | currency | 0.0040 | Дуже слабка | ❌ |
# | 10 | transaction_type | 0.0034 | Дуже слабка | ❌ вже є rate-фічі |
# | 11 | card_brand | 0.0029 | Дуже слабка | ❌ вже є unique_card_brands |
#
# ## Легенда
#
# - ✅ — включити в датасет
# - ⚠️ — опціонально, перевірити чи дає буст F1 в моделі
# - ❌ — не включати (шум / дублікат / не значущий)
#
# ## Підсумок
#
# - **✅ Включити:** 23 фічі + 4 target-encoded категоріальних = **27 фіч**
# - **⚠️ Тестувати:** 5 фіч — додати і перевірити F1 на validation
# - **❌ Відкинути:** 19 фіч
#
# ## Шкала оцінки
#
# **AUC:** 0.80+ = відмінна, 0.70–0.80 = добра, 0.60–0.70 = помірна, 0.55–0.60 = слабка, <0.55 = шум
#
# **Theil's U:** >0.02 = помірна, 0.01–0.02 = слабка, <0.01 = дуже слабка
#
# **Phi (φ):** >0.1 = помірна, 0.03–0.1 = слабка, <0.03 = дуже слабка

# %% [markdown]
# #Setup

# %% [markdown]
# ## Imports

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.11)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pynndescent>=0.5->umap-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.stats import chi2_contingency
import seaborn as sns
from sklearn.preprocessing import TargetEncoder
import umap
from sklearn.metrics import roc_auc_score
from scipy.stats import pointbiserialr
from sklearn.metrics import roc_auc_score
from scipy.stats import pointbiserialr
from scipy.stats import pearsonr
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor, NearestNeighbors
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import classification_report, confusion_matrix

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Config

# %%
root_path = "/content/drive/MyDrive/raw_data"
train_user_data_path = root_path + "/train_users.csv"
train_transaction_data_path = root_path + "/train_transactions.csv"

# %% [markdown]
# # Data Loading

# %%
df_user = pd.read_csv(train_user_data_path)
df_transaction =  pd.read_csv(train_transaction_data_path)

# %% [markdown]
# # EDA — User Data

# %% [markdown]
# ## Overview

# %%
df_user
# Out:
#          id_user                     timestamp_reg                      email  \
# 0       15383249  2025-07-16 19:01:23.868869+00:00    larsjohansson@gmail.com
# 1        9458117  2025-05-04 19:30:02.902877+00:00          evamark@yahoo.com
# 2       21312302         2025-09-07 18:24:51+00:00         stmark86@gmail.com
# 3          61828  2025-01-01 17:33:08.026088+00:00     robertwalker@gmail.com
# 4       13164211  2025-06-21 18:27:03.420098+00:00     sarah.miller@gmail.com
# ...          ...                               ...                        ...
# 395376  15208750  2025-07-15 00:09:30.100536+00:00     alexpaterson@gmail.com
# 395377  34511422         2025-12-22 16:25:42+00:00       kmiller216@gmail.com
# 395378  28313259         2025-11-04 17:41:08+00:00           vams25@gmail.com
# 395379  31685096         2025-12-01 15:28:38+00:00         lrwinpdx@gmail.com
# 395380  24901877         2025-10-09 06:54:01+00:00  jasonmiller2847@gmail.com
#
#         gender    reg_country traffic_type  is_fraud
# 0         male         Sweden          cpa         0
# 1         male        Romania          cpa         0
# 2         male        Austria          ppc         0
# 3         male       Portugal      organic         1
# 4       female        Belgium      organic         0
# ...        ...            ...          ...       ...
# 395376    male  United States          cpa         0
# 395377    male  United States          ppc         0
# 395378    male  United States          ppc         0
# 395379  female  United States          ppc         0
# 395380    male  United States          cpa         0
#
# [395381 rows x 7 columns]

# %%
df_transaction
# Out:
#           id_user                      timestamp_tr  amount   status  \
# 0        15383249         2025-09-06 07:45:39+00:00    3.81     fail
# 1         9458117         2025-10-10 11:23:30+00:00    7.94  success
# 2        21312302         2025-09-07 19:48:45+00:00    3.81  success
# 3           61828  2025-01-02 10:25:02.150802+00:00    3.48     fail
# 4        13164211         2025-12-23 21:56:32+00:00   29.25  success
# ...           ...                               ...     ...      ...
# 3135373  30507985         2025-12-08 05:35:07+00:00    8.95  success
# 3135374  12584522         2025-07-16 15:17:25+00:00   21.00  success
# 3135375  13612852         2025-08-05 03:30:11+00:00   21.00     fail
# 3135376   5752365         2025-03-21 08:21:55+00:00    3.00  success
# 3135377   7102667         2025-11-23 00:51:37+00:00    2.00     fail
#
#         transaction_type   error_group currency  card_brand card_type  \
# 0         card_recurring     antifraud      EUR  MASTERCARD     DEBIT
# 1              card_init           NaN      EUR        VISA     DEBIT
# 2         card_recurring           NaN      EUR  MASTERCARD     DEBIT
# 3              card_init     antifraud      EUR        VISA     DEBIT
# 4         card_recurring           NaN      EUR  MASTERCARD    CREDIT
# ...                  ...           ...      ...         ...       ...
# 3135373   card_recurring           NaN      USD  MASTERCARD     DEBIT
# 3135374   card_recurring           NaN      USD        VISA     DEBIT
# 3135375   card_recurring         fraud      USD        VISA     DEBIT
# 3135376   card_recurring           NaN      USD        VISA     DEBIT
# 3135377   card_recurring  do not honor      USD        VISA     DEBIT
#
#           card_country        card_holder    card_mask_hash payment_country
# 0               Sweden     johansson lars  24fe124163d8a8fd          Sweden
# 1              Romania         mark evans  c363e0db18c5eca8         Romania
# 2              Austria       mark stevens  553fa6ecd2fef3a7         Austria
# 3             Portugal      felipe felipe  83717e93d7e75536        Portugal
# 4              Belgium       sarah miller  d46d8d6af130a374   United States
# ...                ...                ...               ...             ...
# 3135373  United States       gregory vane  f8fb133fc1cb8e07   United States
# 3135374  United States  felicity harrison  0c77ad1169ca45e2     Philippines
# 3135375  United States   arthur m bennett  0923a167cae6017b   United States
# 3135376  United States      robert carter  8821518cda8a979e         Ukraine
# 3135377  United States  michael henderson  6e84ba19b6a04376   United States
#
# [3135378 rows x 13 columns]

# %% [markdown]
# ## Class Balance

# %%
cnt_froud = df_user[df_user['is_fraud'] == 1]['is_fraud'].count()
cnt_user = df_user.shape[0]
fraud_percentage = (cnt_froud / cnt_user ) *100

print(f"number of user: {cnt_user}")
print(f"number of froud user: {cnt_froud}")
print(f"fraud percentage: {fraud_percentage:.5}%")
# Out:
# number of user: 395381
# number of froud user: 14932
# fraud percentage: 3.7766%

# %%
df_user['is_fraud'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_fraud'>

# %% [markdown]
# ## Schema & Missing Values

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395381 entries, 0 to 395380
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id_user        395381 non-null  int64
#  1   timestamp_reg  395381 non-null  object
#  2   email          395063 non-null  object
#  3   gender         395381 non-null  object
#  4   reg_country    395255 non-null  object
#  5   traffic_type   395381 non-null  object
#  6   is_fraud       395381 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 21.1+ MB

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3135378 entries, 0 to 3135377
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id_user           int64
#  1   timestamp_tr      object
#  2   amount            float64
#  3   status            object
#  4   transaction_type  object
#  5   error_group       object
#  6   currency          object
#  7   card_brand        object
#  8   card_type         object
#  9   card_country      object
#  10  card_holder       object
#  11  card_mask_hash    object
#  12  payment_country   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 311.0+ MB

# %% [markdown]
# ## Categorical Features — Fraud Rate

# %% [markdown]
# ### domain extraction + analysis

# %%
df_user['email'].dropna().apply(lambda x: x.split('@')[1]).unique()
# Out:
# array(['gmail.com', 'yahoo.com', 'hotmail.com', 'outlook.com'],
#       dtype=object)

# %%
df_user['domain'] = df_user['email'].apply(lambda x: x.split('@')[1] if pd.notna(x) else 'missing')
df_user
# Out:
#          id_user                     timestamp_reg                      email  \
# 0       15383249  2025-07-16 19:01:23.868869+00:00    larsjohansson@gmail.com
# 1        9458117  2025-05-04 19:30:02.902877+00:00          evamark@yahoo.com
# 2       21312302         2025-09-07 18:24:51+00:00         stmark86@gmail.com
# 3          61828  2025-01-01 17:33:08.026088+00:00     robertwalker@gmail.com
# 4       13164211  2025-06-21 18:27:03.420098+00:00     sarah.miller@gmail.com
# ...          ...                               ...                        ...
# 395376  15208750  2025-07-15 00:09:30.100536+00:00     alexpaterson@gmail.com
# 395377  34511422         2025-12-22 16:25:42+00:00       kmiller216@gmail.com
# 395378  28313259         2025-11-04 17:41:08+00:00           vams25@gmail.com
# 395379  31685096         2025-12-01 15:28:38+00:00         lrwinpdx@gmail.com
# 395380  24901877         2025-10-09 06:54:01+00:00  jasonmiller2847@gmail.com
#
#         gender    reg_country traffic_type  is_fraud     domain
# 0         male         Sweden          cpa         0  gmail.com
# 1         male        Romania          cpa         0  yahoo.com
# 2         male        Austria          ppc         0  gmail.com
# 3         male       Portugal      organic         1  gmail.com
# 4       female        Belgium      organic         0  gmail.com
# ...        ...            ...          ...       ...        ...
# 395376    male  United States          cpa         0  gmail.com
# 395377    male  United States          ppc         0  gmail.com
# 395378    male  United States          ppc         0  gmail.com
# 395379  female  United States          ppc         0  gmail.com
# 395380    male  United States          cpa         0  gmail.com
#
# [395381 rows x 8 columns]

# %%
fraud_by_domain = df_user[df_user['is_fraud'] == 1].groupby('domain')['is_fraud'].count().reset_index()
fraud_by_domain.columns = ['domain', 'fraud_count']
display(fraud_by_domain.sort_values(by='fraud_count', ascending=False))
# Out:
#         domain  fraud_count
# 0    gmail.com        13082
# 4    yahoo.com         1110
# 1  hotmail.com          441
# 3  outlook.com          272
# 2      missing           27

# %%
total_users_by_domain = df_user.groupby('domain').size().reset_index(name='total_users')
domain_fraud_percentage = pd.merge(fraud_by_domain, total_users_by_domain, on='domain', how='left')
domain_fraud_percentage['fraud_percentage'] = (domain_fraud_percentage['fraud_count'] / domain_fraud_percentage['total_users']) * 100
display(domain_fraud_percentage.sort_values(by='fraud_percentage', ascending=False))
# Out:
#         domain  fraud_count  total_users  fraud_percentage
# 2      missing           27          318          8.490566
# 3  outlook.com          272         5552          4.899135
# 0    gmail.com        13082       341532          3.830388
# 4    yahoo.com         1110        33702          3.293573
# 1  hotmail.com          441        14277          3.088884

# %% [markdown]
# ### fraud rate by cat_columns

# %%
cat_columns = df_user.select_dtypes(include='object').columns.tolist()
cat_columns = [col for col in cat_columns if col not in ['timestamp_reg', 'email']]
print(cat_columns)
# Out:
# ['gender', 'reg_country', 'traffic_type', 'domain']

# %%
for col in cat_columns:
  fraud_rate = df_user.groupby(col)['is_fraud'].mean().sort_values(ascending=False)
  fraud_rate.plot(kind='bar', title=f'{col}')
  plt.show()

# %% [markdown]
# ### fraud rate by reg_country

# %%
fraud_rate_bt_reg_country = df_user.groupby('reg_country')['is_fraud'].mean().sort_values(ascending=False)

# %%
fraud_rate_bt_reg_country.head(10)
# Out:
# reg_country
# Afghanistan          1.00
# Egypt                1.00
# Ghana                1.00
# Zimbabwe             1.00
# Norfolk Island       1.00
# Nigeria              1.00
# Indonesia            1.00
# Ukraine              0.65
# Falkland Islands     0.50
# Wallis and Futuna    0.50
# Name: is_fraud, dtype: float64

# %%
mean_user_per_country = df_user['reg_country'].value_counts().mean()
print(f"mean user per country:  {mean_user_per_country}")
# Out:
# mean user per country:  1838.3953488372092

# %%
fraud_rate_bt_reg_country[df_user['reg_country'].value_counts() >= 1800]
# Out:
# reg_country
# Netherlands       0.064410
# Argentina         0.046056
# France            0.045092
# Germany           0.044794
# Brazil            0.044494
# Canada            0.040064
# United States     0.038850
# Kenya             0.028978
# South Africa      0.025334
# Mexico            0.025322
# Australia         0.024134
# Spain             0.023789
# New Zealand       0.023479
# United Kingdom    0.022048
# Ireland           0.021988
# Italy             0.021340
# Chile             0.018143
# Name: is_fraud, dtype: float64

# %%
fraud_rate_bt_reg_country[df_user['reg_country'].value_counts() < 1800]
# Out:
# reg_country
# Afghanistan       1.0
# Egypt             1.0
# Ghana             1.0
# Zimbabwe          1.0
# Norfolk Island    1.0
#                  ...
# Suriname          0.0
# Tuvalu            0.0
# Venezuela         0.0
# Vanuatu           0.0
# Vatican           0.0
# Name: is_fraud, Length: 198, dtype: float64

# %% [markdown]
# ###  Chi-Squared tests

# %%
print("chi2 — сила відхилення від 'незалежності'. Чим більше — тим сильніший зв'язок")
print("p-value < 0.05 — зв'язок не випадковий (відкидаємо H₀ про незалежність)\n")
for col in cat_columns:
    contingency = pd.crosstab(df_user[col], df_user['is_fraud'])
    chi2, p_value, dof, expected = chi2_contingency(contingency)
    print(f"{col}: chi2={chi2:.2f}, p-value={p_value:.6f}")
# Out:
# chi2 — сила відхилення від 'незалежності'. Чим більше — тим сильніший зв'язок
# p-value < 0.05 — зв'язок не випадковий (відкидаємо H₀ про незалежність)
#
# gender: chi2=2059.47, p-value=0.000000
# reg_country: chi2=7879.39, p-value=0.000000
# traffic_type: chi2=8278.04, p-value=0.000000
# domain: chi2=81.64, p-value=0.000000

# %% [markdown]
# ## Other

# %%
df_user[
    (df_user['id_user'].isin(
        df_transaction[df_transaction['error_group'] == 'fraud']['id_user'].unique())
    ) &
    (df_user['is_fraud'] == 1)
    ]
# Out:
#          id_user                     timestamp_reg                    email  \
# 25      10134016  2025-05-13 19:24:27.731968+00:00   joaoxasdsilv@gmail.com
# 26      10552975  2025-05-19 05:37:15.222237+00:00   johnmiller55@gmail.com
# 32      15800396  2025-07-20 19:14:43.970510+00:00  j-o-h-n-s99@hotmail.com
# 62       2242815  2025-01-29 09:43:27.440881+00:00         carlom@gmail.com
# 86      16470759  2025-07-27 02:52:04.748951+00:00       baker184@gmail.com
# ...          ...                               ...                      ...
# 391837  14050900  2025-07-02 07:15:29.389414+00:00      davidm249@yahoo.com
# 392050  19818351         2025-08-27 00:21:07+00:00  sarahmiller54@gmail.com
# 392439  36070994         2025-12-30 21:26:59+00:00     bwilson942@gmail.com
# 392709  30647462         2025-11-22 21:05:40+00:00  Tabitha.s5821@gmail.com
# 394227  14653810  2025-07-09 03:02:26.358245+00:00      emmarose4@yahoo.com
#
#         gender    reg_country traffic_type  is_fraud       domain
# 25        male        Belgium          cpa         1    gmail.com
# 26        male        Finland          cpa         1    gmail.com
# 32        male         Turkey          ppc         1  hotmail.com
# 62        male      Argentina          ppc         1    gmail.com
# 86      female    Puerto Rico          ppc         1    gmail.com
# ...        ...            ...          ...       ...          ...
# 391837    male  United States          ppc         1    yahoo.com
# 392050  female  United States      organic         1    gmail.com
# 392439  female  United States          cpa         1    gmail.com
# 392709    male  United States          cpa         1    gmail.com
# 394227  female  United States          ppc         1    yahoo.com
#
# [5951 rows x 8 columns]

# %%
df_user[
    (df_user['id_user'].isin(
        df_transaction[df_transaction['error_group'] == 'fraud']['id_user'].unique())
    ) &
    (df_user['is_fraud'] == 1)
    ]['id_user']
# Out:
# 25        10134016
# 26        10552975
# 32        15800396
# 62         2242815
# 86        16470759
#             ...
# 391837    14050900
# 392050    19818351
# 392439    36070994
# 392709    30647462
# 394227    14653810
# Name: id_user, Length: 5951, dtype: int64

# %% [markdown]
# ### Cramér's V

# %%
merged = df_transaction.merge(
    df_user,
    on='id_user'
)
merged
# Out:
#           id_user                      timestamp_tr  amount   status  \
# 0        15383249         2025-09-06 07:45:39+00:00    3.81     fail
# 1         9458117         2025-10-10 11:23:30+00:00    7.94  success
# 2        21312302         2025-09-07 19:48:45+00:00    3.81  success
# 3           61828  2025-01-02 10:25:02.150802+00:00    3.48     fail
# 4        13164211         2025-12-23 21:56:32+00:00   29.25  success
# ...           ...                               ...     ...      ...
# 3135373  30507985         2025-12-08 05:35:07+00:00    8.95  success
# 3135374  12584522         2025-07-16 15:17:25+00:00   21.00  success
# 3135375  13612852         2025-08-05 03:30:11+00:00   21.00     fail
# 3135376   5752365         2025-03-21 08:21:55+00:00    3.00  success
# 3135377   7102667         2025-11-23 00:51:37+00:00    2.00     fail
#
#         transaction_type   error_group currency  card_brand card_type  \
# 0         card_recurring     antifraud      EUR  MASTERCARD     DEBIT
# 1              card_init           NaN      EUR        VISA     DEBIT
# 2         card_recurring           NaN      EUR  MASTERCARD     DEBIT
# 3              card_init     antifraud      EUR        VISA     DEBIT
# 4         card_recurring           NaN      EUR  MASTERCARD    CREDIT
# ...                  ...           ...      ...         ...       ...
# 3135373   card_recurring           NaN      USD  MASTERCARD     DEBIT
# 3135374   card_recurring           NaN      USD        VISA     DEBIT
# 3135375   card_recurring         fraud      USD        VISA     DEBIT
# 3135376   card_recurring           NaN      USD        VISA     DEBIT
# 3135377   card_recurring  do not honor      USD        VISA     DEBIT
#
#           card_country        card_holder    card_mask_hash payment_country  \
# 0               Sweden     johansson lars  24fe124163d8a8fd          Sweden
# 1              Romania         mark evans  c363e0db18c5eca8         Romania
# 2              Austria       mark stevens  553fa6ecd2fef3a7         Austria
# 3             Portugal      felipe felipe  83717e93d7e75536        Portugal
# 4              Belgium       sarah miller  d46d8d6af130a374   United States
# ...                ...                ...               ...             ...
# 3135373  United States       gregory vane  f8fb133fc1cb8e07   United States
# 3135374  United States  felicity harrison  0c77ad1169ca45e2     Philippines
# 3135375  United States   arthur m bennett  0923a167cae6017b   United States
# 3135376  United States      robert carter  8821518cda8a979e         Ukraine
# 3135377  United States  michael henderson  6e84ba19b6a04376   United States
#
#                             timestamp_reg                       email  gender  \
# 0        2025-07-16 19:01:23.868869+00:00     larsjohansson@gmail.com    male
# 1        2025-05-04 19:30:02.902877+00:00           evamark@yahoo.com    male
# 2               2025-09-07 18:24:51+00:00          stmark86@gmail.com    male
# 3        2025-01-01 17:33:08.026088+00:00      robertwalker@gmail.com    male
# 4        2025-06-21 18:27:03.420098+00:00      sarah.miller@gmail.com  female
# ...                                   ...                         ...     ...
# 3135373         2025-11-21 16:51:00+00:00     arthur1miller@gmail.com    male
# 3135374  2025-06-14 08:44:36.467752+00:00    felicitybenson@gmail.com  female
# 3135375  2025-06-27 02:07:28.021085+00:00       artybennett@gmail.com    male
# 3135376  2025-03-18 03:52:03.787806+00:00  carterrobert1958@gmail.com  female
# 3135377  2025-04-05 02:24:35.508175+00:00        markthefox@gmail.com    male
#
#            reg_country traffic_type  is_fraud     domain
# 0               Sweden          cpa         0  gmail.com
# 1              Romania          cpa         0  yahoo.com
# 2              Austria          ppc         0  gmail.com
# 3             Portugal      organic         1  gmail.com
# 4              Belgium      organic         0  gmail.com
# ...                ...          ...       ...        ...
# 3135373  United States          ppc         0  gmail.com
# 3135374  United States          cpa         0  gmail.com
# 3135375  United States          ppc         0  gmail.com
# 3135376  United States          cpa         1  gmail.com
# 3135377  United States          ppc         1  gmail.com
#
# [3135378 rows x 20 columns]

# %%
# раниться хвилин 5, можна скіпати

def cramers_v(x, y):
    contingency = pd.crosstab(x, y)
    chi2 = chi2_contingency(contingency)[0]
    n = len(x)
    min_dim = min(contingency.shape) - 1
    return np.sqrt(chi2 / (n * min_dim)) if min_dim > 0 else 0

cat_cols = ['gender', 'reg_country', 'traffic_type', 'domain',
            'status', 'transaction_type', 'card_brand', 'card_type',
            'currency', 'card_country', 'payment_country']

cramer_matrix = pd.DataFrame(index=cat_cols, columns=cat_cols, dtype=float)
for c1 in cat_cols:
    for c2 in cat_cols:
        cramer_matrix.loc[c1, c2] = cramers_v(merged[c1].fillna('NA'), merged[c2].fillna('NA'))

sns.heatmap(cramer_matrix.astype(float), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Theil's U

# %%
from scipy.stats import entropy

def theils_u(x, y):
    contingency = pd.crosstab(x, y)
    y_probs = contingency.sum(axis=0) / contingency.sum().sum()
    h_y = entropy(y_probs)
    x_probs = contingency.sum(axis=1) / contingency.sum().sum()
    h_y_given_x = 0
    for i in range(contingency.shape[0]):
        row = contingency.iloc[i]
        if row.sum() > 0:
            p = row / row.sum()
            h_y_given_x += (row.sum() / contingency.sum().sum()) * entropy(p)
    return (h_y - h_y_given_x) / h_y if h_y > 0 else 0

for col in cat_cols:
    u = theils_u(merged[col].fillna('NA'), merged['is_fraud'])
    print(f"{col} → is_fraud: Theil's U = {u:.4f}")
# Out:
# gender → is_fraud: Theil's U = 0.0175
# reg_country → is_fraud: Theil's U = 0.0240
# traffic_type → is_fraud: Theil's U = 0.0087
# domain → is_fraud: Theil's U = 0.0046
# status → is_fraud: Theil's U = 0.0117
# transaction_type → is_fraud: Theil's U = 0.0034
# card_brand → is_fraud: Theil's U = 0.0029
# card_type → is_fraud: Theil's U = 0.0051
# currency → is_fraud: Theil's U = 0.0040
# card_country → is_fraud: Theil's U = 0.0251
# payment_country → is_fraud: Theil's U = 0.0241

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# #### create fail_status_coefficient feature

# %%
failed_transactions_per_user = merged[merged['status'] == 'fail'].groupby('id_user').size()
total_transactions_per_user = merged.groupby('id_user').size()

fail_status_coefficient = (failed_transactions_per_user / total_transactions_per_user).fillna(0)

# Convert the fail_status_coefficient Series to a DataFrame and reset the index
fail_status_coefficient_df = fail_status_coefficient.reset_index(name='fail_status_coefficient')

df_user = pd.merge(df_user, fail_status_coefficient_df, on='id_user', how='left')
df_user['fail_status_coefficient'] = df_user['fail_status_coefficient'].fillna(0)

# %% [markdown]
# #### create is_cvv_error feature

# %%
k = 10

df_transaction['timestamp_tr'] = pd.to_datetime(df_transaction['timestamp_tr'], format='ISO8601')

# Sort transactions by user and timestamp, then group to find CVV errors in last k transactions
def check_cvv_error_in_last_k(transactions_df, k_val):
    sorted_transactions = transactions_df.sort_values(by='timestamp_tr', ascending=False).head(k_val)
    return 'cvv error' in sorted_transactions['error_group'].values

is_cvv_error_series = df_transaction.groupby('id_user').apply(lambda x: check_cvv_error_in_last_k(x, k))
is_cvv_error_df = is_cvv_error_series.reset_index(name='is_cvv_error')

# Merge with df_user
df_user = pd.merge(df_user, is_cvv_error_df, on='id_user', how='left')
df_user['is_cvv_error'] = df_user['is_cvv_error'].fillna(False) # Fill NaN for users with no transactions or no CVV errors
# Out:
# /tmp/ipykernel_1559/1258397497.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   is_cvv_error_series = df_transaction.groupby('id_user').apply(lambda x: check_cvv_error_in_last_k(x, k))

# %% [markdown]
# #### create cvv_error_coef feature

# %%
# Calculate the number of 'cvv error' transactions per user
cvv_error_transactions_per_user = df_transaction[df_transaction['error_group'] == 'cvv error'].groupby('id_user').size()

# Calculate the total number of transactions per user
total_transactions_per_user = df_transaction.groupby('id_user').size()

# Calculate the 'cvv_error_conf' coefficient
cvv_error_conf = (cvv_error_transactions_per_user / total_transactions_per_user).fillna(0)

# Convert to a DataFrame and reset index to merge
cvv_error_conf_df = cvv_error_conf.reset_index(name='cvv_error_coef')

# Merge with df_user
df_user = pd.merge(df_user, cvv_error_conf_df, on='id_user', how='left')
df_user['cvv_error_coef'] = df_user['cvv_error_coef'].fillna(0) # Fill NaN for users with no transactions or no CVV errors

# %% [markdown]
# #### create country_CP_missmatch_coef feature

# %%
df_transaction['country_CP_missmatch'] = (df_transaction['card_country'] != df_transaction['payment_country'])

# %%
# Calculate the number of transactions with country_CP_missmatch = True per user
mismatched_country_transactions_per_user = df_transaction[df_transaction['country_CP_missmatch'] == True].groupby('id_user').size()

# Calculate the total number of transactions per user
total_transactions_per_user = df_transaction.groupby('id_user').size()

# Calculate the country_CP_missmatch_coef
country_CP_missmatch_coef = (mismatched_country_transactions_per_user / total_transactions_per_user).fillna(0)

# Convert to a DataFrame and reset index to merge
country_CP_missmatch_coef_df = country_CP_missmatch_coef.reset_index(name='country_CP_missmatch_coef')

# Merge with df_user
df_user = pd.merge(df_user, country_CP_missmatch_coef_df, on='id_user', how='left')
df_user['country_CP_missmatch_coef'] = df_user['country_CP_missmatch_coef'].fillna(0) # Fill NaN for users with no transactions or no mismatches

# %% [markdown]
# #### create unique_cards_per_user feature

# %%
# Calculate the number of unique card_mask_hash per user
unique_cards_per_user = df_transaction.groupby('id_user')['card_mask_hash'].nunique()

# Convert to a DataFrame and reset index to merge
unique_cards_per_user_df = unique_cards_per_user.reset_index(name='unique_cards_per_user')

# Merge with df_user
df_user = pd.merge(df_user, unique_cards_per_user_df, on='id_user', how='left')
df_user['unique_cards_per_user'] = df_user['unique_cards_per_user'].fillna(0) # Fill NaN for users with no transactions

# %% [markdown]
# #### create time_to_first_transaction feature

# %%
df_user['timestamp_reg'] = pd.to_datetime(df_user['timestamp_reg'], format='ISO8601').dt.floor('S')

# Calculate the first transaction timestamp for each user and merge it directly
first_transaction_time_series = df_transaction.groupby('id_user')['timestamp_tr'].min()
df_user['first_timestamp_tr'] = df_user['id_user'].map(first_transaction_time_series)

# Ensure 'first_timestamp_tr' is datetime type after mapping and remove milliseconds
df_user['first_timestamp_tr'] = pd.to_datetime(df_user['first_timestamp_tr'], format='ISO8601', errors='coerce').dt.floor('S')

# Calculate the time difference and convert to total seconds
df_user['time_to_first_transaction'] = (df_user['first_timestamp_tr'] - df_user['timestamp_reg']).dt.total_seconds()
# Out:
# /tmp/ipykernel_1559/3032602584.py:1: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df_user['timestamp_reg'] = pd.to_datetime(df_user['timestamp_reg'], format='ISO8601').dt.floor('S')
# /tmp/ipykernel_1559/3032602584.py:8: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df_user['first_timestamp_tr'] = pd.to_datetime(df_user['first_timestamp_tr'], format='ISO8601', errors='coerce').dt.floor('S')

# %% [markdown]
# #### create fraud_error_rate feature

# %%
fraud_error_per_user = df_transaction[df_transaction['error_group'] == 'fraud'].groupby('id_user').size()
total_per_user = df_transaction.groupby('id_user').size()
df_user['fraud_error_rate'] = df_user['id_user'].map(fraud_error_per_user / total_per_user).fillna(0)

# %% [markdown]
# #### create fraud_error_count feature

# %%
df_user['fraud_error_count'] = df_user['id_user'].map(fraud_error_per_user).fillna(0)

# %% [markdown]
# #### create tx_count feature

# %%
df_user['tx_count'] = df_user['id_user'].map(total_per_user).fillna(0)

# %% [markdown]
# #### create country_CReg_missmatch feature

# %%
tx_with_reg = df_transaction.merge(df_user[['id_user', 'reg_country']], on='id_user')
tx_with_reg['card_reg_mismatch'] = (tx_with_reg['card_country'] != tx_with_reg['reg_country'])
card_reg_mismatch_rate = tx_with_reg.groupby('id_user')['card_reg_mismatch'].mean()
df_user['country_CReg_missmatch'] = df_user['id_user'].map(card_reg_mismatch_rate).fillna(0)

# %% [markdown]
# #### create unique_error_types feature

# %%
unique_errors = df_transaction.groupby('id_user')['error_group'].nunique()
df_user['unique_error_types'] = df_user['id_user'].map(unique_errors).fillna(0)

# %% [markdown]
# #### create unique_card_countries feature

# %%
unique_card_countries = df_transaction.groupby('id_user')['card_country'].nunique()
df_user['unique_card_countries'] = df_user['id_user'].map(unique_card_countries).fillna(0)

# %% [markdown]
# #### create amount features

# %%
amount_agg = df_transaction.groupby('id_user')['amount'].agg([
    'mean', 'std', 'max', 'min', 'median', 'sum'
]).rename(columns={
    'mean': 'amount_mean',
    'std': 'amount_std',
    'max': 'amount_max',
    'min': 'amount_min',
    'median': 'amount_median',
    'sum': 'amount_sum'
})
amount_agg['amount_std'] = amount_agg['amount_std'].fillna(0)
amount_agg['amount_range'] = amount_agg['amount_max'] - amount_agg['amount_min']
amount_agg['amount_cv'] = amount_agg['amount_std'] / (amount_agg['amount_mean'] + 1e-6)

df_user = df_user.merge(amount_agg, on='id_user', how='left')

# %% [markdown]
# #### create transaction_type_resign_rate

# %%
resign_count = df_transaction[df_transaction['transaction_type'] == 'resign'].groupby('id_user').size()
df_user['resign_count'] = df_user['id_user'].map(resign_count).fillna(0)
df_user['transaction_type_resign_rate'] = df_user['resign_count'] / (df_user['tx_count'] + 1e-6)

# %% [markdown]
# #### create time features feature

# %%
df_user['timestamp_reg'] = pd.to_datetime(df_user['timestamp_reg'])
df_user['reg_hour'] = df_user['timestamp_reg'].dt.hour
df_user['reg_dayofweek'] = df_user['timestamp_reg'].dt.dayofweek
df_user['reg_is_night'] = ((df_user['reg_hour'] >= 0) & (df_user['reg_hour'] < 6)).astype(int)
df_user['reg_is_weekend'] = (df_user['reg_dayofweek'] >= 5).astype(int)

# %% [markdown]
# ####  card_holder features

# %%
# Витягнути ім'я з email
df_user['email_name'] = df_user['email'].apply(
    lambda x: x.split('@')[0].lower() if pd.notna(x) else ''
)

# Найчастіший card_holder для кожного юзера
most_common_holder = df_transaction.groupby('id_user')['card_holder'].agg(
    lambda x: x.mode().iloc[0] if len(x.mode()) > 0 else ''
)
df_user['main_card_holder'] = df_user['id_user'].map(most_common_holder).fillna('')

# Простий check — чи перше слово з card_holder є в email
df_user['name_in_email'] = df_user.apply(
    lambda row: any(
        part in row['email_name']
        for part in row['main_card_holder'].split()
        if len(part) > 2
    ), axis=1
).astype(int)

# Кількість різних card_holders на юзера (fraud = багато різних імен)
unique_holders = df_transaction.groupby('id_user')['card_holder'].nunique()
df_user['unique_card_holders'] = df_user['id_user'].map(unique_holders).fillna(0)

# %% [markdown]
# ### AUC & Point-Biserial r

# %%
numeric_features = [
    'unique_cards_per_user',
    'fraud_error_rate',
    'fraud_error_count',
    'tx_count',
    'country_CP_missmatch_coef',
    'unique_error_types',
    'unique_card_countries',
    'unique_card_holders',
    'fail_status_coefficient',
    'cvv_error_coef',
    'amount_mean',
    'amount_std',
    'amount_max',
    'amount_sum',
    'amount_cv',
    'amount_range',
    'transaction_type_resign_rate',
    'reg_hour',
    'reg_is_night',
    'name_in_email',
    'time_to_first_transaction',
    'country_CReg_missmatch'
]

results = []
for feat in numeric_features:
    if feat not in df_user.columns:
        continue
    mask = df_user[feat].notna()
    if mask.sum() < 100:
        continue
    auc = roc_auc_score(df_user.loc[mask, 'is_fraud'], df_user.loc[mask, feat])
    auc_adj = max(auc, 1 - auc)
    corr, pval = pointbiserialr(df_user.loc[mask, 'is_fraud'], df_user.loc[mask, feat])
    results.append({'feature': feat, 'AUC': auc_adj, 'corr': corr, 'p_value': pval})

results_df = pd.DataFrame(results).sort_values('AUC', ascending=False)
print(results_df.to_string(index=False))
# Out:
#                      feature      AUC      corr       p_value
#          unique_card_holders 0.803506  0.324944  0.000000e+00
#           unique_error_types 0.802529  0.283556  0.000000e+00
#        unique_cards_per_user 0.796626  0.289642  0.000000e+00
#                     tx_count 0.729207  0.120681  0.000000e+00
#      fail_status_coefficient 0.714091  0.151119  0.000000e+00
#                   amount_sum 0.695559  0.101900  0.000000e+00
#    country_CP_missmatch_coef 0.663300  0.152448  0.000000e+00
#       country_CReg_missmatch 0.643421  0.162218  0.000000e+00
#            fraud_error_count 0.630776  0.132665  0.000000e+00
#             fraud_error_rate 0.616313  0.062627  0.000000e+00
#                 amount_range 0.563700  0.087160  0.000000e+00
#                   amount_std 0.555680  0.046742 4.445517e-190
#                    amount_cv 0.554471  0.044660 1.103508e-173
#    time_to_first_transaction 0.553697 -0.016812  4.014766e-26
#                name_in_email 0.549939 -0.041282 1.120402e-148
#        unique_card_countries 0.549328  0.126559  0.000000e+00
# transaction_type_resign_rate 0.542223  0.038248 6.764900e-128
#               cvv_error_coef 0.530164  0.000673  6.720117e-01
#                   amount_max 0.529649  0.083640  0.000000e+00
#                  amount_mean 0.516060  0.042816 8.674127e-160
#                 reg_is_night 0.501782 -0.001499  3.457482e-01
#                     reg_hour 0.501571 -0.000981  5.374595e-01

# %%
corr, p_value = pearsonr(df_user['is_cvv_error'], df_user['is_fraud'])
print(f"Phi coefficient is_cvv_error = {corr:.4f}, p = {p_value:.2e}")
# Out:
# Phi coefficient is_cvv_error = 0.0256, p = 3.75e-58

# %%
df_user['name_in_email']
# Out:
# 0         1
# 1         1
# 2         1
# 3         0
# 4         1
#          ..
# 395376    0
# 395377    1
# 395378    0
# 395379    0
# 395380    0
# Name: name_in_email, Length: 395381, dtype: int64

# %% [markdown]
# ### Target encoding + UMAP

# %%
encoded = pd.DataFrame()
for col in cat_cols:
    fraud_rates = merged.groupby(col)['is_fraud'].mean()
    encoded[col] = merged[col].map(fraud_rates).fillna(merged['is_fraud'].mean())


reducer = umap.UMAP(n_components=2, random_state=42)
embedding = reducer.fit_transform(encoded.values[:50000])  # sample for speed

plt.scatter(embedding[:, 0], embedding[:, 1],
            c=merged['is_fraud'].iloc[:50000], alpha=0.1, s=1, cmap='coolwarm')
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(

# %% [markdown]
# ### Amount distribution fraud vs legit

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Log-scale histogram
merged[merged['is_fraud']==0]['amount'].apply(np.log1p).hist(
    bins=100, alpha=0.5, label='legit', ax=axes[0])
merged[merged['is_fraud']==1]['amount'].apply(np.log1p).hist(
    bins=100, alpha=0.5, label='fraud', ax=axes[0])
axes[0].legend()
axes[0].set_title('log(amount) distribution')

# Характерні суми
print("Common fraud amounts:")
print(merged[merged['is_fraud']==1]['amount'].value_counts().head(20))
print("\nCommon legit amounts:")
print(merged[merged['is_fraud']==0]['amount'].value_counts().head(20))
# Out:
# Common fraud amounts:
# amount
# 3.00     148369
# 6.00      85249
# 21.00     45854
# 11.00     43059
# 2.00      38236
# 51.00     11286
# 3.17       8387
# 3.18       4809
# 3.16       4457
# 3.12       3519
# 2.08       3060
# 6.41       2989
# 3.79       2814
# 4.00       2812
# 22.66      2592
# 6.44       2370
# 3.81       2364
# 6.30       2009
# 11.83      1971
# 3.78       1956
# Name: count, dtype: int64
#
# Common legit amounts:
# amount
# 3.00     772795
# 6.00     327363
# 2.00     327360
# 21.00    147630
# 11.00    138136
# 3.17      51181
# 51.00     32090
# 2.08      23901
# 3.16      22786
# 3.12      20806
# 3.18      19804
# 6.41      16962
# 2.41      16140
# 3.79      15927
# 1.30      15702
# 3.81      15625
# 2.40      15022
# 4.00      14288
# 2.39      13634
# 3.82      12652
# Name: count, dtype: int64

# %%
merged.groupby('error_group')['is_fraud'].mean().sort_values(ascending=False)
tx_type_pivot = pd.crosstab(
    merged['transaction_type'],
    merged['is_fraud'],
    normalize='columns'
)
print(tx_type_pivot)
# Out:
# is_fraud                 0         1
# transaction_type
# apple-pay         0.064935  0.052855
# card_init         0.235674  0.242552
# card_recurring    0.531772  0.567154
# google-pay        0.138029  0.097353
# resign            0.029590  0.040086

# %% [markdown]
# ### other

# %%
# Комбінації топ-3 фіч
df_user['holders_x_cards'] = df_user['unique_card_holders'] * df_user['unique_cards_per_user']
df_user['errors_x_cards'] = df_user['unique_error_types'] * df_user['unique_cards_per_user']
df_user['holders_per_card'] = df_user['unique_card_holders'] / (df_user['unique_cards_per_user'] + 1e-6)
# >1 означає що один юзер використовує різні імена для однієї картки — дуже підозріло

# %%
df_user['cards_per_tx'] = df_user['unique_cards_per_user'] / (df_user['tx_count'] + 1e-6)
df_user['holders_per_tx'] = df_user['unique_card_holders'] / (df_user['tx_count'] + 1e-6)
df_user['errors_per_tx'] = df_user['unique_error_types'] / (df_user['tx_count'] + 1e-6)
df_user['countries_per_tx'] = df_user['unique_card_countries'] / (df_user['tx_count'] + 1e-6)

# %%
important_errors = ['antifraud', 'do not honor', 'fraud', 'cvv error',
                    'insufficient funds error', '3ds error', 'card problem']
col = []
for err in important_errors:
    err_count = df_transaction[df_transaction['error_group'] == err].groupby('id_user').size()
    col_name = f"error_{err.replace(' ', '_')}_rate"
    col.append(col_name)
    df_user[col_name] = df_user['id_user'].map(err_count / total_per_user).fillna(0)

# %%
df_user['unique_card_brands'] = df_user['id_user'].map(
    df_transaction.groupby('id_user')['card_brand'].nunique()
).fillna(0)

df_user['unique_card_types'] = df_user['id_user'].map(
    df_transaction.groupby('id_user')['card_type'].nunique()
).fillna(0)

# %%
tx_type_counts = df_transaction.groupby(['id_user', 'transaction_type']).size().unstack(fill_value=0)
tx_type_rates = tx_type_counts.div(tx_type_counts.sum(axis=1), axis=0)
tx_type_rates.columns = [f'tx_type_{col}_rate' for col in tx_type_rates.columns]

df_user = df_user.merge(tx_type_rates, on='id_user', how='left').fillna(0)

# %%
tx_sorted = df_transaction.sort_values(['id_user', 'timestamp_tr'])
tx_sorted['time_diff'] = tx_sorted.groupby('id_user')['timestamp_tr'].diff().dt.total_seconds()

time_agg = tx_sorted.groupby('id_user')['time_diff'].agg(['mean', 'min', 'std']).rename(columns={
    'mean': 'avg_time_between_tx',
    'min': 'min_time_between_tx',
    'std': 'std_time_between_tx'
})
df_user = df_user.merge(time_agg, on='id_user', how='left')

# %%
time_agg.columns
# Out:
# Index(['avg_time_between_tx', 'min_time_between_tx', 'std_time_between_tx'], dtype='object')

# %%
numeric_features = [
    'holders_x_cards',
    'errors_x_cards',
    'holders_per_card',
    'cards_per_tx',
    'holders_per_tx',
    'errors_per_tx',
    'countries_per_tx',
    'error_antifraud_rate',
    'error_do_not_honor_rate',
    'error_fraud_rate',
    'error_cvv_error_rate',
    'error_insufficient_funds_error_rate',
    'error_3ds_error_rate',
    'error_card_problem_rate',
    'unique_card_brands',
    'unique_card_types',
    'tx_type_apple-pay_rate',
    'tx_type_card_init_rate',
    'tx_type_card_recurring_rate',
    'tx_type_google-pay_rate',
    'tx_type_resign_rate',
    'avg_time_between_tx',
    'min_time_between_tx',
    'std_time_between_tx'
]

results = []
for feat in numeric_features:
    if feat not in df_user.columns:
        continue
    mask = df_user[feat].notna()
    if mask.sum() < 100:
        continue
    auc = roc_auc_score(df_user.loc[mask, 'is_fraud'], df_user.loc[mask, feat])
    auc_adj = max(auc, 1 - auc)
    corr, pval = pointbiserialr(df_user.loc[mask, 'is_fraud'], df_user.loc[mask, feat])
    results.append({'feature': feat, 'AUC': auc_adj, 'corr': corr, 'p_value': pval})

results_df = pd.DataFrame(results).sort_values('AUC', ascending=False)
print(results_df.to_string(index=False))
# Out:
#                             feature      AUC      corr       p_value
#                      errors_x_cards 0.842374  0.213930  0.000000e+00
#                     holders_x_cards 0.828441  0.173022  0.000000e+00
#                    countries_per_tx 0.698613 -0.136583  0.000000e+00
#                 min_time_between_tx 0.696225 -0.024384  3.756925e-30
#                  unique_card_brands 0.674496  0.213949  0.000000e+00
#                   unique_card_types 0.668709  0.209752  0.000000e+00
#                error_antifraud_rate 0.659617  0.272527  0.000000e+00
#                       errors_per_tx 0.646076  0.049621 5.662192e-214
#                    holders_per_card 0.616702 -0.004896  2.077877e-03
#                    error_fraud_rate 0.616313  0.062627  0.000000e+00
#              tx_type_card_init_rate 0.592475  0.061154  0.000000e+00
#                error_3ds_error_rate 0.579787  0.003604  2.342691e-02
#                      holders_per_tx 0.569107  0.010910  6.878224e-12
#             error_card_problem_rate 0.558971  0.061048 5.928788e-323
#             error_do_not_honor_rate 0.555680  0.000100  9.497381e-01
#                        cards_per_tx 0.552189 -0.059923 3.051207e-311
# error_insufficient_funds_error_rate 0.551827 -0.016157  2.989841e-24
#                 avg_time_between_tx 0.549072 -0.031403  6.938039e-49
#                 tx_type_resign_rate 0.542214  0.038248 6.765437e-128
#                 std_time_between_tx 0.541021 -0.029468  4.775546e-30
#         tx_type_card_recurring_rate 0.530174  0.009357  4.008209e-09
#                error_cvv_error_rate 0.530164  0.000673  6.720117e-01
#             tx_type_google-pay_rate 0.519885 -0.051418 1.288053e-229
#              tx_type_apple-pay_rate 0.517350 -0.038471 2.276013e-129

# %% [markdown]
# ## Anomaly Detection

# %% [markdown]
# ### preprocessing for anomaly detection

# %%
# Числові фічі які гіпотетично будуть у фінальному датасеті, та які зараз використамо для AD
numeric_features = [
    'errors_x_cards', 'holders_x_cards',
    'unique_card_holders', 'unique_error_types', 'unique_cards_per_user',
    'tx_count', 'fail_status_coefficient',
    'countries_per_tx', 'min_time_between_tx', 'amount_sum',
    'unique_card_brands', 'unique_card_types',
    'country_CP_missmatch_coef', 'error_antifraud_rate',
    'errors_per_tx', 'country_CReg_missmatch',
    'fraud_error_count', 'holders_per_card',
    'fraud_error_rate', 'tx_type_card_init_rate',
    'error_3ds_error_rate', 'holders_per_tx', 'amount_range',
]

# %%
# категоріальні фічі які гіпотетично будуть у фінальному датасеті, та які зараз використамо для AD
cat_cols_for_anomaly = ['reg_country', 'gender', 'traffic_type', 'domain']

# %% [markdown]
# encode numeric features

# %%
X = df_user[numeric_features].fillna(0)
y = df_user['is_fraud']

# RobustScaler — стійкий до аутлайєрів (краще за StandardScaler для fraud data)
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# encode categorical feature

# %% [markdown]
# #### skip for now

# %%
# encoded_cats = pd.DataFrame()
# for col in cat_cols_for_anomaly:
#     freq = df_user[col].value_counts(normalize=True)
#     encoded_cats[f'{col}_freq'] = df_user[col].map(freq).fillna(0)

# X_full = pd.concat([df_user[numeric_features].fillna(0), encoded_cats], axis=1)
# X_full_scaled = RobustScaler().fit_transform(X_full)

# %% [markdown]
# OR

# %% [markdown]
# Target encoding (fraud rate)

# %%
# encoded_cats = pd.DataFrame()
# for col in cat_cols_for_anomaly:
#     fraud_rates = df_user.groupby(col)['is_fraud'].mean()
#     encoded_cats[f'{col}_enc'] = df_user[col].map(fraud_rates).fillna(df_user['is_fraud'].mean())

# # Об'єднати з числовими
# X_full = pd.concat([df_user[numeric_features].fillna(0), encoded_cats], axis=1)
# X_full_scaled = RobustScaler().fit_transform(X_full)

# %% [markdown]
# ### Isolation Forest

# %% [markdown]
# usefull

# %%
# === 1. ISOLATION FOREST ===
# Ідея: будує random trees, аномалії ізолюються за менше splits
# contamination = очікувана частка аномалій (ставимо ~fraud rate)
iso = IsolationForest(
    n_estimators=200,
    contamination=0.038,  # ~3.78% fraud rate з твоїх даних
    random_state=42,
    n_jobs=-1
)
iso.fit(X_scaled)

# Два види output:
# 1) Labels: 1 = normal, -1 = anomaly
df_user['iso_label'] = iso.predict(X_scaled)
# 2) Score: менше = більш аномальний (від'ємні = аномалії)
df_user['iso_score'] = iso.decision_function(X_scaled)

# --- Аналіз результатів ---
anomaly_mask = df_user['iso_label'] == -1

print("=== ISOLATION FOREST ===")
print(f"Anomalies detected: {anomaly_mask.sum()}")
print(f"Total fraud users:  {y.sum()}")
print()

# Головне питання: скільки реальних fraud серед знайдених anomalies?
print("Confusion matrix (anomaly vs actual fraud):")
print(pd.crosstab(
    df_user['iso_label'].map({1: 'normal', -1: 'anomaly'}),
    df_user['is_fraud'].map({0: 'legit', 1: 'fraud'}),
    margins=True
))
print()

# Precision: з тих кого IsoForest назвав anomaly — скільки реально fraud?
precision = df_user[anomaly_mask]['is_fraud'].mean()
# Recall: з усіх fraud — скільки IsoForest знайшов?
recall = df_user[anomaly_mask]['is_fraud'].sum() / y.sum()
print(f"Precision: {precision:.4f} (з anomalies — скільки справді fraud)")
print(f"Recall:    {recall:.4f} (з усіх fraud — скільки знайдено)")
print(f"F1:        {2 * precision * recall / (precision + recall + 1e-6):.4f}")
# Out:
# === ISOLATION FOREST ===
# Anomalies detected: 15025
# Total fraud users:  14932
#
# Confusion matrix (anomaly vs actual fraud):
# is_fraud   fraud   legit     All
# iso_label
# anomaly     5804    9221   15025
# normal      9128  371228  380356
# All        14932  380449  395381
#
# Precision: 0.3863 (з anomalies — скільки справді fraud)
# Recall:    0.3887 (з усіх fraud — скільки знайдено)
# F1:        0.3875

# %%
# --- Візуалізація: розподіл iso_score для fraud vs legit ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(df_user[y == 0]['iso_score'], bins=100, alpha=0.5, label='legit', density=True)
axes[0].hist(df_user[y == 1]['iso_score'], bins=100, alpha=0.5, label='fraud', density=True)
axes[0].axvline(x=0, color='red', linestyle='--', label='decision boundary')
axes[0].legend()
axes[0].set_title('Isolation Forest Score Distribution')
axes[0].set_xlabel('score (менше = більш аномальний)')

# Boxplot
data_to_plot = [
    df_user[y == 0]['iso_score'].values,
    df_user[y == 1]['iso_score'].values
]
axes[1].boxplot(data_to_plot, labels=['legit', 'fraud'])
axes[1].set_title('Isolation Forest Score by Class')
axes[1].set_ylabel('score')

plt.tight_layout()
plt.show()

# AUC iso_score як фічі
auc = roc_auc_score(y, -df_user['iso_score'])  # мінус бо менший score = більш аномальний
print(f"\niso_score AUC = {auc:.4f}")
# Out:
# /tmp/ipykernel_1559/2559796969.py:17: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data_to_plot, labels=['legit', 'fraud'])
# iso_score AUC = 0.9121

# %% [markdown]
# ### LOCAL OUTLIER FACTOR (LOF)
# useless - skip

# %%
# Ідея: порівнює локальну густину точки з густиною її сусідів
# Якщо точка в "рідкісному" районі — вона аномальна
# довго обчислюється

lof = LocalOutlierFactor(
    n_neighbors=20,
    contamination=0.038,
    n_jobs=-1
)
lof_labels = lof.fit_predict(X_scaled)  # LOF не має окремого predict — тільки fit_predict

# Score: більше = більш аномальний
df_user['lof_score'] = -lof.negative_outlier_factor_  # інвертуємо: більше = гірше
df_user['lof_label'] = lof_labels

# --- Аналіз ---
lof_anomaly_mask = df_user['lof_label'] == -1

print("=== LOCAL OUTLIER FACTOR ===")
print(f"Anomalies detected: {lof_anomaly_mask.sum()}")
print()
print(pd.crosstab(
    df_user['lof_label'].map({1: 'normal', -1: 'anomaly'}),
    df_user['is_fraud'].map({0: 'legit', 1: 'fraud'}),
    margins=True
))
print()

precision_lof = df_user[lof_anomaly_mask]['is_fraud'].mean()
recall_lof = df_user[lof_anomaly_mask]['is_fraud'].sum() / y.sum()
print(f"Precision: {precision_lof:.4f}")
print(f"Recall:    {recall_lof:.4f}")
print(f"F1:        {2 * precision_lof * recall_lof / (precision_lof + recall_lof + 1e-6):.4f}")

# AUC
auc_lof = roc_auc_score(y, df_user['lof_score'])
print(f"lof_score AUC = {auc_lof:.4f}")

# %% [markdown]
# ###  KNN DISTANCE
# usefull

# %%
# === 3. KNN DISTANCE ===
# Ідея: середня відстань до K найближчих сусідів
# Аномалії = точки далеко від усіх інших

nn = NearestNeighbors(n_neighbors=10, n_jobs=-1)
nn.fit(X_scaled)
distances, indices = nn.kneighbors(X_scaled)

df_user['knn_avg_dist'] = distances.mean(axis=1)  # середня відстань до 10 сусідів
df_user['knn_max_dist'] = distances.max(axis=1)   # максимальна відстань
df_user['knn_5th_dist'] = distances[:, 4]          # відстань до 5-го сусіда

# --- Аналіз ---
print("=== KNN DISTANCE ===")
print("Fraud vs Legit — середня KNN distance:")
print(df_user.groupby('is_fraud')['knn_avg_dist'].describe()[['mean', '50%', '75%', 'max']])
print()

auc_knn = roc_auc_score(y, df_user['knn_avg_dist'])
print(f"knn_avg_dist AUC = {auc_knn:.4f}")
auc_knn_max = roc_auc_score(y, df_user['knn_max_dist'])
print(f"knn_max_dist AUC = {auc_knn_max:.4f}")

# %% [markdown]
# ### Comparing

# %%
# === 4. ПОРІВНЯННЯ ВСІХ МЕТОДІВ ===
print("=== ПОРІВНЯННЯ ANOMALY DETECTION МЕТОДІВ ===\n")

methods = {
    'Isolation Forest': ('iso_score', True),   # True = інвертувати (менше = аномалія)
    # 'LOF': ('lof_score', False),               # False = вже інвертовано
    'KNN avg dist': ('knn_avg_dist', False),
    'KNN max dist': ('knn_max_dist', False),
}

for name, (col, invert) in methods.items():
    score = -df_user[col] if invert else df_user[col]
    auc = roc_auc_score(y, score)
    corr, p = pointbiserialr(y, df_user[col])
    print(f"{name:20s}: AUC = {auc:.4f}, corr = {corr:.4f}")

# --- Яку anomaly-фічу додати в датасет ---
print("\n=== РЕКОМЕНДАЦІЯ ===")
print("Додай в датасет фічі з AUC > 0.55:")
for name, (col, invert) in methods.items():
    score = -df_user[col] if invert else df_user[col]
    auc = roc_auc_score(y, score)
    status = "✅ додати" if auc > 0.55 else "❌ не додавати"
    print(f"  {col:20s}: AUC = {auc:.4f} → {status}")

# %%
# === 5. ВІЗУАЛІЗАЦІЯ: ТОП-2 ФІЧІ + ANOMALY OVERLAY ===
# Scatter plot двох найсильніших фіч з anomaly detection overlay

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Plot 1: Real labels
scatter1 = axes[0].scatter(
    df_user['errors_x_cards'][:50000],
    df_user['unique_card_holders'][:50000],
    c=y[:50000], alpha=0.2, s=3, cmap='coolwarm'
)
axes[0].set_title('Real Labels (red=fraud)')
axes[0].set_xlabel('errors_x_cards')
axes[0].set_ylabel('unique_card_holders')

# Plot 2: Isolation Forest
scatter2 = axes[1].scatter(
    df_user['errors_x_cards'][:50000],
    df_user['unique_card_holders'][:50000],
    c=df_user['iso_score'][:50000], alpha=0.2, s=3, cmap='RdYlGn'
)
axes[1].set_title('Isolation Forest Score')
axes[1].set_xlabel('errors_x_cards')
plt.colorbar(scatter2, ax=axes[1])

# Plot 3: KNN Distance
scatter3 = axes[2].scatter(
    df_user['errors_x_cards'][:50000],
    df_user['unique_card_holders'][:50000],
    c=df_user['knn_avg_dist'][:50000], alpha=0.2, s=3, cmap='RdYlGn_r'
)
axes[2].set_title('KNN Avg Distance')
axes[2].set_xlabel('errors_x_cards')
plt.colorbar(scatter3, ax=axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# # other
